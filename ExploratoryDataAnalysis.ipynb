# %%
import pandas as pd
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import plotly
plotly.__version__
import plotly
from plotly.graph_objs import Scatter, Layout
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# /Library/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
train=pd.read_csv("train_ireg_amd_dmd.csv")
train['index']=train['Unnamed: 0']
del train['Unnamed: 0']

# %%
train.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
train['NumberOfTime30-59DaysPastDueNotWorse']=

# %%
train.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     150000.000000                         150000.000000  150000.000000
# mean           0.066840                              6.048438      52.295553
# std            0.249746                            249.755371      14.771249
# min            0.000000                              0.000000      21.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154181      52.000000
# 75%            0.000000                              0.559046      63.000000
# max            1.000000                          50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         150000.000000  150000.000000   1.500000e+05
# mean                               0.421033     353.005076   6.687979e+03
# ...

# %%
train_discretized=pd.read_csv('train_ireg_amd_dmd_discretized.csv')
train_discretized['index']=train_discretized['Unnamed: 0']
del train_discretized['Unnamed: 0']

# %%
from pandasql import sqldf

# %%
test=pd.read_csv('pred_xgb_record.csv')
test.head()
# Out:
#    index  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0      1               NaN                              0.885519   43
# 1      2               NaN                              0.463295   57
# 2      3               NaN                              0.043275   59
# 3      4               NaN                              0.280308   38
# 4      5               NaN                              1.000000   27
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     0   0.177513         5700.0
# 1                                     0   0.527237         9141.0
# 2                                     0   0.687648         5083.0
# 3                                     1   0.925961         3200.0
# 4                                     0   0.019917         3865.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                                4                        0
# ...

# %%
test=pd.read_csv('pred_xgb_record.csv')
test.head()
test['dlq']=pd.DataFrame(np.ones(test.size))
test.loc[(test['prob']<=0.5), 'dlq'] = int(0)
test[test['dlq']==1]
groupByDependents=test.groupby(['NumberOfDependents', 'dlq']).count()

groupByDependents['index'][:,1]
numberofdependents_dlq=groupByDependents['index'][:,1]/(groupByDependents['index'][:,0] + groupByDependents['index'][:,1])
pd.DataFrame(numberofdependents_dlq)
numberofdependents_dlq=numberofdependents_dlq.dropna()

Xrange=np.arange(0,groupByDependents['age'][:,1].count())

Y=numberofdependents_dlq.as_matrix()
X=Xrange

print Y
d = {'dep_no': X, 'per': Y}
dfoutput=pd.DataFrame(d)
dfoutput.to_csv('dep_per.csv')
# Out:
# [ 0.01340885  0.01798064  0.02225899  0.03065076  0.0406015   0.03231939
#   0.072       0.02      ]

# %%
test=pd.read_csv('pred_xgb_record.csv')
a=test.describe()
a=a.T
a.to_csv('forboxplot.csv')

# %%
#test[test['prob']<=0.5]


#np.zeros(test.size)

test['dlq']=pd.DataFrame(np.ones(test.size))

# %%
#test[test['prob']<=0.5]['dlq']

test.loc[(test['prob']<=0.5), 'dlq'] = int(0)

# %%
test[test['dlq']==1]
# Out:
#          index  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 23          24               NaN                              0.957442   69
# 69          70               NaN                              1.000000   52
# 123        124               NaN                              2.182724   49
# 166        167               NaN                             49.923077   62
# 280        281               NaN                              1.066445   35
# 356        357               NaN                              0.978913   28
# 404        405               NaN                              1.103039   58
# 405        406               NaN                              1.000000   52
# 625        626               NaN                              0.759448   42
# 643        644               NaN                              0.955719   55
# 653        654               NaN                              1.076412   27
# ...

# %%
groupByDependents=test.groupby(['NumberOfDependents', 'dlq']).count()

# %%
groupByDependents
# Out:
#                         index  SeriousDlqin2yrs  \
# NumberOfDependents dlq
# 0.0                0.0  57832                 0
#                    1.0    786                 0
# 1.0                0.0  19880                 0
#                    1.0    364                 0
# 2.0                0.0  13002                 0
#                    1.0    296                 0
# 3.0                0.0   6420                 0
#                    1.0    203                 0
# 4.0                0.0   1914                 0
#                    1.0     81                 0
# 5.0                0.0    509                 0
#                    1.0     17                 0
# 6.0                0.0    116                 0
#                    1.0      9                 0
# 7.0                0.0     49                 0
#                    1.0      1                 0
# 8.0                0.0     16                 0
# 9.0                0.0      3                 0
# ...

# %%
#groupByDependents['age'][0]/groupByDependents['age'][0].sum()
groupByDependents['index'][:,1]
numberofdependents_dlq=groupByDependents['index'][:,1]/(groupByDependents['index'][:,0] + groupByDependents['index'][:,1])

# %%
pd.DataFrame(numberofdependents_dlq)
# Out:
#                        index
# NumberOfDependents
# 0.0                 0.013409
# 1.0                 0.017981
# 2.0                 0.022259
# 3.0                 0.030651
# 4.0                 0.040602
# 5.0                 0.032319
# 6.0                 0.072000
# 7.0                 0.020000
# 8.0                      NaN
# 9.0                      NaN
# 10.0                     NaN
# 20.0                     NaN
# 43.0                     NaN

# %%
numberofdependents_dlq=numberofdependents_dlq.dropna()

Xrange=np.arange(0,groupByDependents['age'][:,1].count())

Y=numberofdependents_dlq.as_matrix()
X=Xrange

print Y
# Out:
# [ 0.01340885  0.01798064  0.02225899  0.03065076  0.0406015   0.03231939
#   0.072       0.02      ]

# %%
print X
print Y
# Out:
# [0 1 2 3 4 5 6 7]
# [ 0.01340885  0.01798064  0.02225899  0.03065076  0.0406015   0.03231939
#   0.072       0.02      ]

# %%
d = {'dep_no': X, 'per': Y}
dfoutput=pd.DataFrame(d)
dfoutput.to_csv('dep_per.csv')

# %%
train_discretized.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127  40s
# 1                 0                              0.957151  40s
# 2                 0                              0.658180  30s
# 3                 0                              0.233810  30s
# 4                 0                              0.907239  40s
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio MonthlyIncome  \
# 0                                     2   0.802982           10K
# 1                                     0   0.121876            5K
# 2                                     1   0.085113            5K
# 3                                     0   0.036050            5K
# 4                                     1   0.024926           20K
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
numberofdependents_dlq=groupByDependents['index'][:,1]/(groupByDependents['index'][:,0] + groupByDependents['index'][:,1])

# %%
groupByDependents=train_discretized.groupby(['NumberOfDependents', 'SeriousDlqin2yrs']).count()

# %%
groupByDependents
# Out:
#                                      RevolvingUtilizationOfUnsecuredLines  \
# NumberOfDependents SeriousDlqin2yrs
# 0.0                0                                                81807
#                    1                                                 5095
# 1.0                0                                                28126
#                    1                                                 2114
# 2.0                0                                                17938
#                    1                                                 1584
# 3.0                0                                                 8646
#                    1                                                  837
# 4.0                0                                                 2565
#                    1                                                  297
# 5.0                0                                                  678
# ...

# %%
#groupByDependents['age'][0]/groupByDependents['age'][0].sum()
groupByDependents['index'][:,1]
numberofdependents_dlq=groupByDependents['index'][:,1]/(groupByDependents['index'][:,0] + groupByDependents['index'][:,1])

# %%
pd.DataFrame(numberofdependents_dlq)
# Out:
#                        index
# NumberOfDependents
# 0.0                 0.058629
# 1.0                 0.069907
# 2.0                 0.081139
# 3.0                 0.088263
# 4.0                 0.103774
# 5.0                 0.091153
# 6.0                 0.151899
# 7.0                 0.098039
# 8.0                 0.083333
# 9.0                      NaN
# 10.0                     NaN
# 13.0                     NaN
# 20.0                     NaN

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import plotly
plotly.__version__
import plotly
from plotly.graph_objs import Scatter, Layout
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True) 

numberofdependents_dlq=numberofdependents_dlq.dropna()

Xrange=np.arange(0,groupByDependents['age'][:,1].count())

Y=numberofdependents_dlq.as_matrix()
X=Xrange

print Y

slope, intercept, r_value, p_value, std_err = stats.linregress(X,Y)
line = slope*X+intercept

trace1 = go.Scatter(
                  x=X, 
                  y=Y, 
                  mode='line',
                  marker=go.Marker(color='rgb((255, 127, 14)'),
                  name='Data'
                  )

trace2 = go.Scatter(
                  x=X, 
                  y=line, 
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='fit'
                  )


annotation = go.Annotation(
                  x=4,
                  y=0.14,
                  text='$R^2 = 0.9551,\\Y = 0.716X + 19.18$',
                  showarrow=False,
                  font=go.Font(size=16)
                  )

layout = go.Layout(
                title='Number of dependents to delinquency',
                plot_bgcolor='rgb(229, 229, 229)',
                  xaxis=go.XAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)'),
                  yaxis=go.YAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)'),
                  annotations=[annotation]
                )

data = [trace1, trace2]

#print x

#data = [trace]

# Plot and embed in ipython notebook!

fig = go.Figure(data=data, layout=layout)
#fig = go.Figure(data=data)

plotly.offline.iplot(fig, filename='Number of dependents to delinquency')
print "We can see that as number of dependents are growing delinquency rate is increasing"
print "R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, "
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# [ 0.05862926  0.06990741  0.08113923  0.08826321  0.10377358  0.09115282
#   0.15189873  0.09803922  0.08333333]
# ...

# %%
test.loc[ (test['age']>=100),'age']='100s'
test.loc[ (test['age']<30) & (test['age']>=20),'age']='20s'
test.loc[ (test['age']<40) & (test['age']>=30),'age']='30s'
test.loc[ (test['age']<50) & (test['age']>=40),'age']='40s'
test.loc[ (test['age']<60) & (test['age']>=50),'age']='50s'
test.loc[ (test['age']<70) & (test['age']>=60),'age']='60s'
test.loc[ (test['age']<80) & (test['age']>=70),'age']='70s'
test.loc[ (test['age']<90) & (test['age']>=80),'age']='80s'
test.loc[ (test['age']<100) & (test['age']>=90),'age']='90s'
test.loc[ (test['age']<20) & (test['age']>=0),'age']='10s'

# %%
groupByAge=test.groupby(['age', 'dlq']).count()
groupByAge['index'][:,1]
age_dlq=groupByAge['index'][:,1]/(groupByAge['index'][:,0] + groupByAge['index'][:,1])

# %%
a=pd.DataFrame(age_dlq)
#a.icol(0)
#print a['index']
pd.age_dlq
# Out:
# age
# 100s         NaN
# 20s     0.030267
# 30s     0.029379
# 40s     0.024250
# 50s     0.017285
# 60s     0.005881
# 70s     0.002791
# 80s     0.000833
# 90s     0.004301
# Name: index, dtype: float64

# %%
test=pd.read_csv('pred_xgb_record.csv')
test.head()

test=pd.read_csv('pred_xgb_record.csv')
test.head()
test['dlq']=pd.DataFrame(np.ones(test.size))
test.loc[(test['prob']<=0.5), 'dlq'] = int(0)
test[test['dlq']==1]


test.loc[ (test['age']>=100),'age']='100s'
test.loc[ (test['age']<25) & (test['age']>=20),'age']='20s'
test.loc[ (test['age']<30) & (test['age']>=25),'age']='25s'

test.loc[ (test['age']<35) & (test['age']>=30),'age']='30s'
test.loc[ (test['age']<40) & (test['age']>=35),'age']='35s'

test.loc[ (test['age']<45) & (test['age']>=40),'age']='40s'
test.loc[ (test['age']<50) & (test['age']>=45),'age']='45s'

test.loc[ (test['age']<55) & (test['age']>=50),'age']='50s'
test.loc[ (test['age']<60) & (test['age']>=55),'age']='55s'

test.loc[ (test['age']<65) & (test['age']>=60),'age']='60s'
test.loc[ (test['age']<70) & (test['age']>=65),'age']='65s'

test.loc[ (test['age']<75) & (test['age']>=70),'age']='70s'
test.loc[ (test['age']<80) & (test['age']>=75),'age']='75s'

test.loc[ (test['age']<85) & (test['age']>=80),'age']='80s'
test.loc[ (test['age']<90) & (test['age']>=85),'age']='85s'

test.loc[ (test['age']<95) & (test['age']>=90),'age']="90s"
test.loc[ (test['age']<100) & (test['age']>=95),'age']="95s"

test.loc[ (test['age']<20) & (test['age']>=0),'age']='10s'



groupByAgeWorse=test.groupby(['age'])
a=groupByAgeWorse.mean()
a.to_csv('allagewise.csv')
a
#test[test['NumberOfDependents']>2]
# Out:
#              index  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# age
# 100s  22049.500000               NaN                              0.185244
# 20s   49535.319742               NaN                              0.583496
# 25s   50793.772474               NaN                              4.218682
# 30s   51339.204073               NaN                              7.656208
# 35s   50241.861937               NaN                              9.456563
# 40s   50507.100475               NaN                              5.924415
# 45s   50806.039300               NaN                              8.839475
# 50s   51085.227742               NaN                              4.879818
# 55s   50444.366452               NaN                              1.221211
# 60s   50936.253224               NaN                              5.904680
# 65s   50980.003407               NaN                              3.940799
# ...

# %%
test=pd.read_csv('pred_xgb_record.csv')
test.head()

test=pd.read_csv('pred_xgb_record.csv')
test.head()
test['dlq']=pd.DataFrame(np.ones(test.size))
test.loc[(test['prob']<=0.5), 'dlq'] = int(0)
test[test['dlq']==1]


test.loc[test['MonthlyIncome']<0,'MonthlyIncome']=0
test.loc[test['MonthlyIncome']>=15000,'MonthlyIncome']=20
test.loc[((test['MonthlyIncome']>=0)&(test['MonthlyIncome']<2500)), 'MonthlyIncome']=2
test.loc[((test['MonthlyIncome']>=2500) & (test['MonthlyIncome']<5000)), 'MonthlyIncome'] =5
test.loc[((test['MonthlyIncome']>=5000) & (test['MonthlyIncome']<7500)), 'MonthlyIncome'] =7
test.loc[((test['MonthlyIncome']>=7500) & (test['MonthlyIncome']<10000)), 'MonthlyIncome'] =10
test.loc[((test['MonthlyIncome']>=10000) & (test['MonthlyIncome']<12500)), 'MonthlyIncome'] =12
test.loc[((test['MonthlyIncome']>=12500) & (test['MonthlyIncome']<15000)), 'MonthlyIncome'] =15



groupByIncomeAll=test.groupby(['MonthlyIncome'])
a=groupByIncomeAll.mean()
a.to_csv('allincomewise.csv')
a
#test[test['NumberOfDependents']>2]
# Out:
#                       index  SeriousDlqin2yrs  \
# MonthlyIncome
# 2.0            50629.636576               NaN
# 5.0            50872.526919               NaN
# 7.0            50805.072628               NaN
# 10.0           50571.715374               NaN
# 12.0           50722.985792               NaN
# 15.0           50864.251017               NaN
#
#                RevolvingUtilizationOfUnsecuredLines        age  \
# MonthlyIncome
# 2.0                                        9.399880  49.534027
# 5.0                                        5.859037  49.049945
# 7.0                                        3.170700  53.566020
# 10.0                                       4.773217  56.517123
# 12.0                                       6.009841  55.111539
# 15.0                                       3.463801  54.177449
#
#                NumberOfTime30-59DaysPastDueNotWorse   DebtRatio  \
# MonthlyIncome
# 2.0                                        1.350347  253.183764
# ...

# %%
test=pd.read_csv('pred_xgb_record.csv')
test.head()

test=pd.read_csv('pred_xgb_record.csv')
test.head()
test['dlq']=pd.DataFrame(np.ones(test.size))
test.loc[(test['prob']<=0.5), 'dlq'] = int(0)
test[test['dlq']==1]


test.loc[ (test['age']>=100),'age']='100s'
test.loc[ (test['age']<30) & (test['age']>=20),'age']='20s'
test.loc[ (test['age']<40) & (test['age']>=30),'age']='30s'
test.loc[ (test['age']<50) & (test['age']>=40),'age']='40s'
test.loc[ (test['age']<60) & (test['age']>=50),'age']='50s'
test.loc[ (test['age']<70) & (test['age']>=60),'age']='60s'
test.loc[ (test['age']<80) & (test['age']>=70),'age']='70s'
test.loc[ (test['age']<90) & (test['age']>=80),'age']='80s'
test.loc[ (test['age']<100) & (test['age']>=90),'age']="90s"
test.loc[ (test['age']<20) & (test['age']>=0),'age']='10s'


groupByAge=test.groupby(['age', 'dlq']).count()
groupByAge['index'][:,1]
age_dlq=groupByAge['index'][:,1]/(groupByAge['index'][:,0] + groupByAge['index'][:,1])



a=pd.DataFrame(age_dlq)
#a.icol(0)
a['index']


age_dlq=age_dlq.dropna()

#-1 as we dont want to take 100
Xrange=np.arange(0,groupByAge['index'][:,1].count())

Y=age_dlq.as_matrix()[0:]
X=Xrange
print X
print Y
#a.unstack(level=-1

import re

_nsre = re.compile('([0-9]+)')
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]  
keys=age_dlq.keys()
keys=list(keys)
keys.sort(key=natural_sort_key)
print keys
print Y





d = {'age': keys, 'per': Y}
dfoutput=pd.DataFrame(d,index=None)
dfoutput.to_csv('age_per.csv')
dfoutput
# Out:
# [0 1 2 3 4 5 6 7]
# [ 0.03026696  0.02937948  0.02424997  0.01728467  0.00588055  0.0027909
#   0.0008331   0.00430108]
# ['20s', '30s', '40s', '50s', '60s', '70s', '80s', '90s']
# [ 0.03026696  0.02937948  0.02424997  0.01728467  0.00588055  0.0027909
#   0.0008331   0.00430108]
#    age       per
# 0  20s  0.030267
# 1  30s  0.029379
# 2  40s  0.024250
# 3  50s  0.017285
# 4  60s  0.005881
# 5  70s  0.002791
# 6  80s  0.000833
# 7  90s  0.004301

# %%
Xrange=np.arange(0,groupByAge['index'][:,1].count()-1)+2
print Xrange
# Out:
# [2 3 4 5 6 7 8]

# %%
age_dlq=age_dlq.dropna()

#-1 as we dont want to take 100
Xrange=np.arange(0,groupByAge['index'][:,1].count())

Y=age_dlq.as_matrix()[0:]
X=Xrange
print X
print Y
#a.unstack(level=-1
# Out:
# [0 1 2 3 4 5 6 7]
# [ 0.03026696  0.02937948  0.02424997  0.01728467  0.00588055  0.0027909
#   0.0008331   0.00430108]

# %%
import re

_nsre = re.compile('([0-9]+)')
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]  
keys=age_dlq.keys()
keys=list(keys)
keys.sort(key=natural_sort_key)
print keys
print Y
# Out:
# ['20s', '30s', '40s', '50s', '60s', '70s', '80s', '90s']
# [ 0.03026696  0.02937948  0.02424997  0.01728467  0.00588055  0.0027909
#   0.0008331   0.00430108]

# %%
d = {'age': keys, 'per': Y}
dfoutput=pd.DataFrame(d,index=None)
dfoutput.to_csv('age_per.csv')

# %%
dfoutput
# Out:
#    age       per
# 0  20s  0.030267
# 1  30s  0.029379
# 2  40s  0.024250
# 3  50s  0.017285
# 4  60s  0.005881
# 5  70s  0.002791
# 6  80s  0.000833
# 7  90s  0.004301

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import plotly
plotly.__version__
import plotly
from plotly.graph_objs import Scatter, Layout
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True) 

age_dlq=age_dlq.dropna()

#-1 as we dont want to take 100
Xrange=np.arange(0,groupByAge['index'][:,1].count()-1)

Y=age_dlq.as_matrix()[1:]
X=Xrange

print Y

slope, intercept, r_value, p_value, std_err = stats.linregress(X,Y)
line = slope*X+intercept

trace1 = go.Scatter(
                  x=X, 
                  y=Y, 
                  mode='line',
                  marker=go.Marker(color='rgb((255, 127, 14)'),
                  name='Data'
                  )

trace2 = go.Scatter(
                  x=X, 
                  y=line, 
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='fit'
                  )


annotation = go.Annotation(
                  x=4,
                  y=0.14,
                  text=r_value,
                  showarrow=False,
                  font=go.Font(size=16)
                  )

layout = go.Layout(
                title='Age to delinquency',
                plot_bgcolor='rgb(229, 229, 229)',
                  xaxis=go.XAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)'),
                  yaxis=go.YAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)'),
                  annotations=[annotation]
                )

data = [trace1, trace2]

#print x

#data = [trace]

# Plot and embed in ipython notebook!

fig = go.Figure(data=data, layout=layout)
#fig = go.Figure(data=data)

plotly.offline.iplot(fig, filename='Age to delinquency')
print "We can see that as age is increasing delinquency is reducing as they become more mature or have enough income"
print "R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, "
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# [ 0.11734694  0.10072036  0.08371877  0.06452892  0.0363259   0.02433645
#   0.0204878   0.01928783]
# ...

# %%
test=pd.read_csv('pred_xgb_record.csv')
test.head()

test=pd.read_csv('pred_xgb_record.csv')
test.head()
test['dlq']=pd.DataFrame(np.ones(test.size))
test.loc[(test['prob']<=0.5), 'dlq'] = int(0)
test[test['dlq']==1]
# Out:
#          index  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 23          24               NaN                              0.957442   69
# 69          70               NaN                              1.000000   52
# 123        124               NaN                              2.182724   49
# 166        167               NaN                             49.923077   62
# 280        281               NaN                              1.066445   35
# 356        357               NaN                              0.978913   28
# 404        405               NaN                              1.103039   58
# 405        406               NaN                              1.000000   52
# 625        626               NaN                              0.759448   42
# 643        644               NaN                              0.955719   55
# 653        654               NaN                              1.076412   27
# ...

# %%
test.loc[test['MonthlyIncome']<0,'MonthlyIncome']=0
test.loc[test['MonthlyIncome']>=15000,'MonthlyIncome']='20K'
test.loc[((test['MonthlyIncome']>=0)&(test['MonthlyIncome']<2500)), 'MonthlyIncome']='2K'
test.loc[((test['MonthlyIncome']>=2500) & (test['MonthlyIncome']<5000)), 'MonthlyIncome'] ='5K'
test.loc[((test['MonthlyIncome']>=5000) & (test['MonthlyIncome']<7500)), 'MonthlyIncome'] ='7K'
test.loc[((test['MonthlyIncome']>=7500) & (test['MonthlyIncome']<10000)), 'MonthlyIncome'] ='10K'
test.loc[((test['MonthlyIncome']>=10000) & (test['MonthlyIncome']<12500)), 'MonthlyIncome'] ='12K'
test.loc[((test['MonthlyIncome']>=12500) & (test['MonthlyIncome']<15000)), 'MonthlyIncome'] ='15K'

# %%
groupByMonthlyIncome=test.groupby(['MonthlyIncome','dlq']).count()
#groupByDependents['age'][0]/groupByDependents['age'][0].sum()
groupByMonthlyIncome['index'][:,1]
income_dlq=groupByMonthlyIncome['index'][:,1]/(groupByMonthlyIncome['index'][:,0] + groupByMonthlyIncome['index'][:,1])


a=pd.DataFrame(income_dlq)
#a.icol(0)



income_dlq=income_dlq.dropna()

#-1 as we dont want to take 100
Xrange=np.arange(0,groupByMonthlyIncome['index'][:,1].count())

Y=income_dlq.as_matrix()[0:]
X=Xrange
print X
print Y
#a.unstack(level=-1




import re

_nsre = re.compile('([0-9]+)')
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]  
keys=income_dlq.keys()
keys=list(keys)
keys.sort(key=natural_sort_key)
print keys

d = {'income': keys, 'per': Y}
dfoutput=pd.DataFrame(d,index=None)
dfoutput.to_csv('income_per.csv')
dfoutput
#income_dlq=income_dlq[keys]
#for key in keys:
#    print income_dlq[key]
# Out:
# [0 1 2 3 4 5 6]
# [ 0.00722144  0.0059753   0.00406654  0.00416992  0.02699309  0.02941609
#   0.0145256 ]
# ['2K', '5K', '7K', '10K', '12K', '15K', '20K']
#   income       per
# 0     2K  0.007221
# 1     5K  0.005975
# 2     7K  0.004067
# 3    10K  0.004170
# 4    12K  0.026993
# 5    15K  0.029416
# 6    20K  0.014526

# %%
groupByMonthlyIncome=train_discretized.groupby(['MonthlyIncome','SeriousDlqin2yrs']).count()

# %%
groupByMonthlyIncome
# Out:
#                                 RevolvingUtilizationOfUnsecuredLines    age  \
# MonthlyIncome SeriousDlqin2yrs
# 10K           0                                                23873  23873
#               1                                                 1151   1151
# 12K           0                                                10681  10681
#               1                                                  447    447
# 15K           0                                                 4101   4101
#               1                                                  195    195
# 20K           0                                                 5504   5504
#               1                                                  268    268
# 2K            0                                                15543  15543
#               1                                                 1576   1576
# 5K            0                                                36101  36101
# ...

# %%
#groupByDependents['age'][0]/groupByDependents['age'][0].sum()
groupByMonthlyIncome['index'][:,1]
income_dlq=groupByMonthlyIncome['index'][:,1]/(groupByMonthlyIncome['index'][:,0] + groupByMonthlyIncome['index'][:,1])

# %%
import re

_nsre = re.compile('([0-9]+)')
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]  
keys=income_dlq.keys()
keys=list(keys)
keys.sort(key=natural_sort_key)
print keys

income_dlq=income_dlq[keys]
#for key in keys:
#    print income_dlq[key]
# Out:
# ['2K', '5K', '7K', '10K', '12K', '15K', '20K']

# %%
print X
# Out:
# [0 1 2 3 4 5]

# %%
#groupByDependents['age'][0]/groupByDependents['age'][0].sum()
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import plotly
plotly.__version__
import plotly
from plotly.graph_objs import Scatter, Layout
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True) 

income_dlq=income_dlq.dropna()

#-1 as we dont want to take 100
Xrange=np.arange(0,groupByMonthlyIncome['index'][:,1].count())

Y=income_dlq.as_matrix()
X=Xrange

print keys
print Y

slope, intercept, r_value, p_value, std_err = stats.linregress(X,Y)
line = slope*X+intercept

trace1 = go.Scatter(
                  x=X, 
                  y=Y, 
                  mode='line',
                  marker=go.Marker(color='rgb((255, 127, 14)'),
                  name='Data'
                  )

trace2 = go.Scatter(
                  x=X, 
                  y=line, 
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='fit'
                  )


annotation = go.Annotation(
                  x=4,
                  y=0.14,
                  text=r_value,
                  showarrow=False,
                  font=go.Font(size=16)
                  )

layout = go.Layout(
                title='Income to delinquency',
                plot_bgcolor='rgb(229, 229, 229)',
                  xaxis=go.XAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)'),
                  yaxis=go.YAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)'),
                  annotations=[annotation]
                )

data = [trace1, trace2]

#print x

#data = [trace]

# Plot and embed in ipython notebook!

fig = go.Figure(data=data, layout=layout)
#fig = go.Figure(data=data)


plotly.offline.iplot(fig, filename='Income to delinquency')
print "We can see that as income is increasing delinquency is decreasing thats very intuitive"
print "R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination"
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ['2K', '5K', '7K', '10K', '12K', '15K', '20K']
# [ 0.09206145  0.09325865  0.05712212  0.04599584  0.04016894  0.04539106
#   0.04643105]
# ...

# %%
bins = np.linspace(test.RevolvingUtilizationOfUnsecuredLines.min(), test.RevolvingUtilizationOfUnsecuredLines.max(),50 )
groupByutilization = test.groupby([pd.cut(test.RevolvingUtilizationOfUnsecuredLines, bins),'dlq']).count()

#groupByDependents=train_discretized.groupby(['NumberOfDependents', 'SeriousDlqin2yrs']).count()

# %%
groupByutilization
# Out:
#                                             index  SeriousDlqin2yrs  \
# RevolvingUtilizationOfUnsecuredLines dlq
# (0, 445.327]                         0.0  92321.0               0.0
#                                      1.0   1746.0               0.0
# (445.327, 890.653]                   0.0     15.0               0.0
#                                      1.0      NaN               NaN
# (890.653, 1335.98]                   0.0     19.0               0.0
#                                      1.0      NaN               NaN
# (1335.98, 1781.306]                  0.0     12.0               0.0
#                                      1.0      NaN               NaN
# (1781.306, 2226.633]                 0.0     12.0               0.0
#                                      1.0      NaN               NaN
# (2226.633, 2671.959]                 0.0      4.0               0.0
#                                      1.0      NaN               NaN
# ...

# %%
#groupByDependents['age'][0]/groupByDependents['age'][0].sum()
groupByutilization['index'][:,1]
utilization_dlq=groupByutilization['index'][:,1]/(groupByutilization['index'][:,0] + groupByutilization['index'][:,1])

utilization_dlq


utilization_dlq=utilization_dlq.dropna()

#-1 as we dont want to take 100
Xrange=np.arange(0,groupByutilization['index'][:,1].count())

Y=utilization_dlq.as_matrix()
X=Xrange

print Y


import re

_nsre = re.compile('([0-9]+)')
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]  
keys=utilization_dlq.keys()
print keys
keys=list(keys)
keys.sort(key=natural_sort_key)
print keys
# Out:
# [ 0.01856124  0.25        0.33333333]
# Index([u'(0, 445.327]', u'(4007.939, 4453.265]', u'(7570.551, 8015.878]'], dtype='object', name=u'RevolvingUtilizationOfUnsecuredLines')
# ['(0, 445.327]', '(4007.939, 4453.265]', '(7570.551, 8015.878]']

# %%
utilization_dlq=utilization_dlq.dropna()

#-1 as we dont want to take 100
Xrange=np.arange(0,groupByutilization['index'][:,1].count())

Y=utilization_dlq.as_matrix()
X=Xrange

print Y


import re

_nsre = re.compile('([0-9]+)')
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower()
            for text in re.split(_nsre, s)]  
keys=utilization_dlq.keys()
keys=list(keys)
keys.sort(key=natural_sort_key)
print keys



d = {'utilization': keys, 'per': Y}
dfoutput=pd.DataFrame(d,index=None)
dfoutput.to_csv('utilization_per.csv')
dfoutput

#groupByDependents=train_discretized.groupby(['NumberOfDependents', 'SeriousDlqin2yrs']).count()
# Out:
# [ 0.01856124  0.25        0.33333333]
# ['(0, 445.327]', '(4007.939, 4453.265]', '(7570.551, 8015.878]']
#         per           utilization
# 0  0.018561          (0, 445.327]
# 1  0.250000  (4007.939, 4453.265]
# 2  0.333333  (7570.551, 8015.878]

# %%
bins = np.linspace(train_discretized.RevolvingUtilizationOfUnsecuredLines.min(), train_discretized.RevolvingUtilizationOfUnsecuredLines.max(),50 )
groupByutilization = train_discretized.groupby([pd.cut(train_discretized.RevolvingUtilizationOfUnsecuredLines, bins),'SeriousDlqin2yrs']).count()

#groupByDependents=train_discretized.groupby(['NumberOfDependents', 'SeriousDlqin2yrs']).count()

# %%
#groupByDependents['age'][0]/groupByDependents['age'][0].sum()
groupByutilization['index'][:,1]
utilization_dlq=groupByutilization['index'][:,1]/(groupByutilization['index'][:,0] + groupByutilization['index'][:,1])

# %%
utilization_dlq
# Out:
# RevolvingUtilizationOfUnsecuredLines
# (0, 1034.857]             0.069779
# (1034.857, 2069.714]      0.055556
# (2069.714, 3104.571]      0.033333
# (3104.571, 4139.429]      0.148148
# (4139.429, 5174.286]           NaN
# (5174.286, 6209.143]      0.111111
# (6209.143, 7244]               NaN
# (7244, 8278.857]               NaN
# (8278.857, 9313.714]      0.200000
# (9313.714, 10348.571]          NaN
# (10348.571, 11383.429]         NaN
# (11383.429, 12418.286]         NaN
# (12418.286, 13453.143]         NaN
# (13453.143, 14488]             NaN
# (14488, 15522.857]             NaN
# (15522.857, 16557.714]         NaN
# (16557.714, 17592.571]         NaN
# (17592.571, 18627.429]         NaN
# (18627.429, 19662.286]         NaN
# (19662.286, 20697.143]         NaN
# (20697.143, 21732]             NaN
# (21732, 22766.857]             NaN
# (22766.857, 23801.714]         NaN
# (23801.714, 24836.571]         NaN
# (24836.571, 25871.429]         NaN
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import plotly
plotly.__version__
import plotly
from plotly.graph_objs import Scatter, Layout
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True) 

utilization_dlq=utilization_dlq.dropna()

#-1 as we dont want to take 100
Xrange=np.arange(0,groupByutilization['index'][:,1].count())

Y=utilization_dlq.as_matrix()
X=Xrange

print Y

slope, intercept, r_value, p_value, std_err = stats.linregress(X,Y)
line = slope*X+intercept

trace1 = go.Scatter(
                  x=X, 
                  y=Y, 
                  mode='line',
                  marker=go.Marker(color='rgb((255, 127, 14)'),
                  name='Data'
                  )

trace2 = go.Scatter(
                  x=X, 
                  y=line, 
                  mode='lines',
                  marker=go.Marker(color='rgb(31, 119, 180)'),
                  name='fit'
                  )


annotation = go.Annotation(
                  x=4,
                  y=0.14,
                  text=r_value,
                  showarrow=False,
                  font=go.Font(size=16)
                  )

layout = go.Layout(
                title='Credit Utilization to delinquency',
                plot_bgcolor='rgb(229, 229, 229)',
                  xaxis=go.XAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)'),
                  yaxis=go.YAxis(zerolinecolor='rgb(255,255,255)', gridcolor='rgb(255,255,255)'),
                  annotations=[annotation]
                )

data = [trace1, trace2]

#print x

#data = [trace]

# Plot and embed in ipython notebook!

fig = go.Figure(data=data, layout=layout)
#fig = go.Figure(data=data)

plotly.offline.iplot(fig, filename='Credit Utilization to delinquency')
print "This is expected as higher the credit utilization, more likely they are to default or late"
print "R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, "
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# [ 0.06977949  0.05555556  0.03333333  0.14814815  0.11111111  0.2       ]
# ...
